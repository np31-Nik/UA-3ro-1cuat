# %% [markdown]
# # Práctica 2: clasificación de dígitos MNIST mediante AdaBoost

# %% [markdown]
# **Introducción**

# %% [markdown]
# Importar librerías

# %%
import numpy as np
import matplotlib.pyplot as plt
import random
import math
from keras.datasets import mnist

# %% [markdown]
# Desde la libería de Keras podemos descargar la base datos MNIST

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
x_train.shape,y_train.shape
# Out:
# ((60000, 28, 28), (60000,))

# %% [markdown]
# Guardar base de datos en un fichero

# %%
np.savez("mnist",x=x_train,y=y_train)

# %% [markdown]
# Cargar base de datos desde un fichero

# %%
npzfile = np.load("mnist.npz")
mnist_X = npzfile['x']
mnist_Y = npzfile['y']
mnist_X.shape
# Out:
# (60000, 28, 28)

# %% [markdown]
# Mostrar una imagen de MNIST

# %%
plt.figure()
plt.imshow(x_train[40])
plt.show()
print("Etiqueta: " + str(y_train[40]))
# Out:
# Etiqueta: 1

# %% [markdown]
# **Implementación AdaBoost**

# %% [markdown]
# Adaptación de los arrays de imágenes y etiquetas para AdaBoost:
# Lo que hacemos es cambiar la forma de la matriz X, para que sea un simple vector de 60000x784, utilizando reshape()

# %%
def adaptar_conjuntos(X, Y):
    X = mnist_X.reshape(60000,28*28)
    Y = mnist_Y
    return (X,Y)
(X,Y) = adaptar_conjuntos(mnist_X, mnist_Y)

# %% [markdown]
# Funcion para especificar la clase que utilizaremos:
# En este caso modificamos el vector Y, para que en caso de que el valor de Y[i] corresponda al valor de la clase, este elemento cuente como un '1', en caso contrario sera '-1'

# %%
def clase(Y,clase):
    Ytemp = np.full(len(Y),0)
    for i in range(len(Y)):
        if Y[i]==clase:
            Ytemp[i]= 1
        else:
            Ytemp[i]= -1
    #print(Ytemp)
    return Ytemp

# %% [markdown]
# Funciones necesarias para los clasificadores débiles

# %%
# Dimensión con la que vamos a trabajar. En nuestro caso 28*28
def generar_clasificador_debil(dimension_datos):
    pixel = random.randint(0,dimension_datos-1)
    umbral = random.randint(0,255) 
    booleano_dir = random.randint(0,1)

    if booleano_dir == 0:
        direccion = -1
    else:
        direccion = 1

    return (pixel,umbral,direccion) # Devolvemos el clasificador debil generado

# %%
def aplicar_clasificador_debil(clasificador, imagen):
    pixel = clasificador[0]
    umbral = clasificador[1]
    direccion = clasificador[2]

    if direccion == 1:
        if imagen[pixel] >= umbral:
            res = True
        else:
            res = False
    else:
        
        if imagen[pixel] < umbral:
            
            res = True
        else:
            res = False

    return res

# %%
def obtener_error(clasificador, X, Y, D):
    error = 0.0

    for i in range(len(X)):
        if aplicar_clasificador_debil(clasificador,X[i]):
            if Y[i] != 1:
                error = error + D[i]
        else:
            if Y[i] == 1:
                error = error + D[i]

    return error

# %% [markdown]
# Funcion de entrenamiento para un clasificador fuerte:

# %%
def entrenar(X, Y, T, A):
    clasificadores_debiles = []
    alfas = []
    D = np.full(len(X), 1/len(X))
    tam_img = 28*28

    for t in range(T):

        min_cd=((),2)

        for k in range(A):

            cd = generar_clasificador_debil(tam_img)
            error = obtener_error(cd,X,Y,D)

            if error < min_cd[1] or min_cd[1] == 2:
                min_cd=(cd,error)

        clasificadores_debiles.append(min_cd[0])

        if min_cd[1]<=0:
            alfa=1/2
        else:
            alfa = (1/2) * math.log( (1-min_cd[1])/min_cd[1] ,2)


        alfas.append(alfa)

        Z=np.sum(D)
        Dtemp=np.copy(D)

        for x in range(len(X)):
            if aplicar_clasificador_debil(min_cd[0],X[x]):
                cd_d=1
            else:
                cd_d=-1
            
            Dtemp[x]=D[x]*np.exp(-alfa*Y[x]*cd_d)

        D = Dtemp/Z
            
    return (clasificadores_debiles, alfas)

# %% [markdown]
# Funcion para aplicar un clasificador fuerte a un conjunto de imagenes:

# %%
def aplicarCF(H,X):
    res=np.full(len(X),0.0)

    for x in range(len(X)):
        h=0.0
        for i in range(len(H[0])):
            cd_res=aplicar_clasificador_debil(H[0][i],X[x])
            if cd_res:
                cd_res=1
            else:
                cd_res=-1

            h += H[1][i]*cd_res
        res[x]=h

    res = np.sign(res)
    res = res.astype(int)
    return res

# %% [markdown]
# Análisis y resultados de las pruebas realizadas

# %% [markdown]
# Las siguientes 2 funciones se utilizan para obtener tanto el numero de aciertos como el porcentaje de aciertos, la parte comentada puede ser util para depurar y ver los resultados exactos.

# %%
def comparar(res,Y):
    aciertos=0
    for y in range(len(Y)):
        if res[y]==Y[y]:
            aciertos+=1

    return round(aciertos/len(Y)*100,2)

# %%
def resultados(cf_img,Y,tam_muestra):
    print('lenY:',len(Y))
    aciertos = 0.0
    aciertosC = np.full(10,0.0)
    fallos = 0.0
    fallosC = np.full(10,0.0)
    for i in range(tam_muestra):
        for j in range(10):
            if cf_img[i][j] == 1 and Y[i]==j:
                aciertos+=1
                aciertosC[j]+=1
            elif Y[i]!=j and cf_img[i][j] == 1:
                fallos+=1
                fallosC[j]+=1
    print('Aciertos Total:',aciertos)
    print('Fallos Total:',fallos)

    for j in range(10):
        count = sum(map(lambda x : x==j,Y[:tam_muestra]))
        print('Clase:',j,' Aciertos:',aciertosC[j],' Fallos:',fallosC[j],' img(',j,'):',count,' Porcentaje de aciertos:',round(aciertosC[j]/count*100,2),'%','Porcentaje de fallos:',round(fallosC[j]/tam_muestra*100,2))
    print('Imagenes = ',tam_muestra,' | A = ',A,' | T = ',T,' | Porcentaje de aciertos(Total) = ',round(aciertos/tam_muestra*100,2),'%','Porcentaje de fallos(Total) = ',round(fallos/tam_muestra*100,2))

# %% [markdown]
# Para dividir el conjunto de entrenamiento y test, lo que se ha hecho es utilizar las primeras N imagenes del vector X para el entrenamiento, luego para realizar las pruebas se utiliza el rango N*(p-1)+ hasta N*p, donde p es el numero de la prueba actual, en el codigo siguiente se puede ver como se utiliza:

# %% [markdown]
# Para utilizar el conjunto de prueba tenemos la siguiente funcion:

# %%
def pruebas(Hlista,Y,tam_muestra):

    P = 10 #Num de pruebas
    for p in range(2,P):
        muestra_hasta = tam_muestra*p
        muestra_desde = tam_muestra*(p-1)+1
        if(muestra_hasta > 60000):
            muestra_hasta=60000
            
        for c in range(10):
            Yclase = clase(Y,c)

            Xtest = X[muestra_desde:muestra_hasta]
            Ytest = Yclase[muestra_desde:muestra_hasta]

            resTest = aplicarCF(Hlista[c],Xtest)
            porcentajeTest = comparar(resTest,Ytest)

            for i in range(tam_muestra-1):
                cf_img[i][c] = resTest[i]
                #print('c=',c,'resTest[i]=',resTest[i],' cf_img[i][c]=',cf_img[i][c],' Y[i]=',Y[i],' Ytest[i]=',Ytest[i])

            print('clase: ',c,' resultados test[',muestra_desde,'-',muestra_hasta,']: ',porcentajeTest)
        
        if(muestra_hasta==60000):
            break

        print('Resultados de prueba para: |',muestra_desde,' - ',muestra_hasta,'|:')
        Yr = Y[muestra_desde:muestra_hasta]
        print('desde:',muestra_desde,'hasta:',muestra_hasta)
        resultados(cf_img,Yr,len(Yr))

# %% [markdown]
# A continuacion se encuentra el codigo principal, donde declaramos nuestros parametros T,A, y el tam_muestra (cantidad de imagenes a utilizar para entrenar y por prueba), ademas en esta parte del codigo llamamos al entrenamiento para cada clase(0-9), y guardamos los clasificadores fuertes(H) en una lista (Hlista)

# %%
T = 100 #num cd a usar
A = 1000 #num pruebas aleatorias para cada cd
tam_muestra=1000
cf_img = np.full((tam_muestra,10),[0])
Hlista = []
for c in range(10):
    Yclase = clase(Y,c)

    Xtrain=X[:tam_muestra]
    Ytrain=Yclase[:tam_muestra]

    H = entrenar(Xtrain, Ytrain, T, A)
    Hlista.append(H)
    print('Entrenado')
    res = aplicarCF(H,Xtrain)

    for i in range(tam_muestra):
        cf_img[i][c] = res[i]
        print('c=',c,'res[i]=',res[i],' cf_img[i][c]=',cf_img[i][c],' Y[i]=',Y[i],' Ytrain[i]=',Ytrain[i])

    porcentajeEntrenamiento = comparar(res,Ytrain)

    print('clase: ',c,' (T:',T,' A:',A,') resultados train[',tam_muestra,']: ',porcentajeEntrenamiento,'%')
print('len:',len(Hlista),' Hlista:',Hlista)
print('Resultados de entrenamiento:')
resultados(cf_img,Y,tam_muestra)

pruebas(Hlista,Y,tam_muestra)
# Out:
# Entrenado
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 5  Ytrain[i]= -1
# c= 0 res[i]= 1  cf_img[i][c]= 1  Y[i]= 0  Ytrain[i]= 1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 4  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 9  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 2  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 3  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 4  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 3  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 5  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 3  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 6  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 7  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 2  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 8  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 6  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 9  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 4  Ytrain[i]= -1
# c= 0 res[i]= 1  cf_img[i][c]= 1  Y[i]= 0  Ytrain[i]= 1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 9  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 2  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 4  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 3  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 2  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 7  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 3  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 8  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 6  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 9  Ytrain[i]= -1
# c= 0 res[i]= 1  cf_img[i][c]= 1  Y[i]= 0  Ytrain[i]= 1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 5  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 6  Ytrain[i]= -1
# c= 0 res[i]= 1  cf_img[i][c]= 1  Y[i]= 0  Ytrain[i]= 1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 7  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 6  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 8  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 7  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 9  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 3  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 9  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 8  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 5  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 9  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 3  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 3  Ytrain[i]= -1
# c= 0 res[i]= 1  cf_img[i][c]= 1  Y[i]= 0  Ytrain[i]= 1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 7  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 4  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 9  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 8  Ytrain[i]= -1
# c= 0 res[i]= 1  cf_img[i][c]= 1  Y[i]= 0  Ytrain[i]= 1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 9  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 4  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 4  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 4  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 6  Ytrain[i]= -1
# c= 0 res[i]= 1  cf_img[i][c]= 1  Y[i]= 0  Ytrain[i]= 1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 4  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 5  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 6  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= 1  cf_img[i][c]= 1  Y[i]= 0  Ytrain[i]= 1
# c= 0 res[i]= 1  cf_img[i][c]= 1  Y[i]= 0  Ytrain[i]= 1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 7  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 6  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 3  Ytrain[i]= -1
# c= 0 res[i]= 1  cf_img[i][c]= 1  Y[i]= 0  Ytrain[i]= 1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 2  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 7  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 9  Ytrain[i]= -1
# c= 0 res[i]= 1  cf_img[i][c]= 1  Y[i]= 0  Ytrain[i]= 1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 2  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 6  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 7  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 8  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 3  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 9  Ytrain[i]= -1
# c= 0 res[i]= 1  cf_img[i][c]= 1  Y[i]= 0  Ytrain[i]= 1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 4  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 6  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 7  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 4  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 6  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 8  Ytrain[i]= -1
# c= 0 res[i]= 1  cf_img[i][c]= 1  Y[i]= 0  Ytrain[i]= 1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 7  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 8  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 3  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 5  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 7  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 7  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 6  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 3  Ytrain[i]= -1
# c= 0 res[i]= 1  cf_img[i][c]= 1  Y[i]= 0  Ytrain[i]= 1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 2  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 9  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 3  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= 1  cf_img[i][c]= 1  Y[i]= 0  Ytrain[i]= 1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 4  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 9  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 2  Ytrain[i]= -1
# c= 0 res[i]= 1  cf_img[i][c]= 1  Y[i]= 0  Ytrain[i]= 1
# c= 0 res[i]= 1  cf_img[i][c]= 1  Y[i]= 0  Ytrain[i]= 1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 2  Ytrain[i]= -1
# c= 0 res[i]= 1  cf_img[i][c]= 1  Y[i]= 0  Ytrain[i]= 1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 2  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 7  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 8  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 6  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 4  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 6  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 3  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 4  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 5  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 9  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 3  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 3  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 8  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 5  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 4  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 7  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 7  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 4  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 2  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 8  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 5  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 8  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 6  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 7  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 3  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 4  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 6  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 9  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 9  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 6  Ytrain[i]= -1
# c= 0 res[i]= 1  cf_img[i][c]= 1  Y[i]= 0  Ytrain[i]= 1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 3  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 7  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 2  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 8  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 2  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 9  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 4  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 4  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 6  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 4  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 9  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 7  Ytrain[i]= -1
# c= 0 res[i]= 1  cf_img[i][c]= 1  Y[i]= 0  Ytrain[i]= 1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 9  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 2  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 9  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 5  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 5  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 9  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 2  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 3  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 2  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 3  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 5  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 9  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 7  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 6  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 2  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 8  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 2  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 2  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 5  Ytrain[i]= -1
# c= 0 res[i]= 1  cf_img[i][c]= 1  Y[i]= 0  Ytrain[i]= 1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 7  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 4  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 9  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 7  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 8  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 3  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 2  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 8  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 3  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 6  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= 1  cf_img[i][c]= 1  Y[i]= 0  Ytrain[i]= 1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 3  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= 1  cf_img[i][c]= 1  Y[i]= 0  Ytrain[i]= 1
# c= 0 res[i]= 1  cf_img[i][c]= 1  Y[i]= 0  Ytrain[i]= 1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 7  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 2  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 7  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 3  Ytrain[i]= -1
# c= 0 res[i]= 1  cf_img[i][c]= 1  Y[i]= 0  Ytrain[i]= 1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 4  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 6  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 5  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 2  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 6  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 4  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 7  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 8  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 9  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 9  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 3  Ytrain[i]= -1
# c= 0 res[i]= 1  cf_img[i][c]= 1  Y[i]= 0  Ytrain[i]= 1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 7  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= 1  cf_img[i][c]= 1  Y[i]= 0  Ytrain[i]= 1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 2  Ytrain[i]= -1
# c= 0 res[i]= 1  cf_img[i][c]= 1  Y[i]= 0  Ytrain[i]= 1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 3  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 5  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 4  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 6  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 5  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 8  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 6  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 3  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 7  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 5  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 8  Ytrain[i]= -1
# c= 0 res[i]= 1  cf_img[i][c]= 1  Y[i]= 0  Ytrain[i]= 1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 9  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= 1  cf_img[i][c]= 1  Y[i]= 0  Ytrain[i]= 1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 3  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 2  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 2  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 3  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 3  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 6  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 4  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 7  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 5  Ytrain[i]= -1
# c= 0 res[i]= 1  cf_img[i][c]= 1  Y[i]= 0  Ytrain[i]= 1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 6  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 2  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 7  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 9  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 8  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 5  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 9  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 2  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 4  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 4  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 5  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 6  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 4  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 2  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 5  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 3  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 9  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 3  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 9  Ytrain[i]= -1
# c= 0 res[i]= 1  cf_img[i][c]= 1  Y[i]= 0  Ytrain[i]= 1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 5  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 9  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 6  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 5  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 7  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 4  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 3  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 4  Ytrain[i]= -1
# c= 0 res[i]= 1  cf_img[i][c]= 1  Y[i]= 0  Ytrain[i]= 1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 4  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 8  Ytrain[i]= -1
# c= 0 res[i]= 1  cf_img[i][c]= 1  Y[i]= 0  Ytrain[i]= 1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 4  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 3  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 6  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 8  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 7  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 6  Ytrain[i]= -1
# c= 0 res[i]= 1  cf_img[i][c]= 1  Y[i]= 0  Ytrain[i]= 1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 9  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 7  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 5  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 7  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 2  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 6  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 8  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 9  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 4  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 5  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 2  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 2  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 9  Ytrain[i]= -1
# c= 0 res[i]= 1  cf_img[i][c]= 1  Y[i]= 0  Ytrain[i]= 1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 3  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 9  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 6  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 7  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 2  Ytrain[i]= -1
# c= 0 res[i]= 1  cf_img[i][c]= 1  Y[i]= 0  Ytrain[i]= 1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 3  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 5  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 4  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 3  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 6  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 5  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 8  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 9  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 5  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 4  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 7  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 4  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 2  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 7  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 3  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 4  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 8  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 9  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 9  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 2  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 8  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 7  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 9  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 8  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 7  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 4  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 3  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= 1  cf_img[i][c]= 1  Y[i]= 0  Ytrain[i]= 1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 2  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 3  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 9  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 4  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 9  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 2  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 6  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 8  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 4  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 7  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 7  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 4  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 4  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 9  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 2  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 5  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 7  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 2  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 4  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 4  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 2  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 9  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 7  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 2  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 8  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 7  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 6  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 9  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 2  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 2  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 3  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 8  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 6  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 5  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= 1  cf_img[i][c]= 1  Y[i]= 0  Ytrain[i]= 1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 2  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 6  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 4  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 5  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 8  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 3  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 5  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 9  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 2  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 7  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 4  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 4  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 4  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 8  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 5  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 8  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 9  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 5  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 6  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 7  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 9  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 9  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 3  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 7  Ytrain[i]= -1
# c= 0 res[i]= 1  cf_img[i][c]= 1  Y[i]= 0  Ytrain[i]= 1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 9  Ytrain[i]= -1
# c= 0 res[i]= 1  cf_img[i][c]= 1  Y[i]= 0  Ytrain[i]= 1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 6  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 6  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 2  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 3  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 9  Ytrain[i]= -1
# c= 0 res[i]= 1  cf_img[i][c]= 1  Y[i]= 0  Ytrain[i]= 1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 7  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 5  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 4  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 8  Ytrain[i]= -1
# c= 0 res[i]= 1  cf_img[i][c]= 1  Y[i]= 0  Ytrain[i]= 1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 9  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 4  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 2  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 8  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 7  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 2  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 6  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= 1  cf_img[i][c]= 1  Y[i]= 0  Ytrain[i]= 1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 3  Ytrain[i]= -1
# c= 0 res[i]= 1  cf_img[i][c]= 1  Y[i]= 0  Ytrain[i]= 1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 8  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 2  Ytrain[i]= -1
# c= 0 res[i]= 1  cf_img[i][c]= 1  Y[i]= 0  Ytrain[i]= 1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 3  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 9  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 4  Ytrain[i]= -1
# c= 0 res[i]= 1  cf_img[i][c]= 1  Y[i]= 0  Ytrain[i]= 1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 5  Ytrain[i]= -1
# c= 0 res[i]= 1  cf_img[i][c]= 1  Y[i]= 0  Ytrain[i]= 1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 6  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 7  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 7  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 8  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 9  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 2  Ytrain[i]= -1
# c= 0 res[i]= 1  cf_img[i][c]= 1  Y[i]= 0  Ytrain[i]= 1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 5  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 2  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 2  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 7  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 3  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 5  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 4  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 9  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 7  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 8  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 3  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 9  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 6  Ytrain[i]= -1
# c= 0 res[i]= 1  cf_img[i][c]= 1  Y[i]= 0  Ytrain[i]= 1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 3  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 2  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 6  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 3  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 5  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 7  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 6  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 8  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 3  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 9  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 5  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 8  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 5  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 7  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 6  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 3  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 7  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 5  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 5  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 5  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 2  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 5  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 8  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 7  Ytrain[i]= -1
# c= 0 res[i]= 1  cf_img[i][c]= 1  Y[i]= 0  Ytrain[i]= 1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 9  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 7  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 7  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 5  Ytrain[i]= -1
# c= 0 res[i]= 1  cf_img[i][c]= 1  Y[i]= 0  Ytrain[i]= 1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 9  Ytrain[i]= -1
# c= 0 res[i]= 1  cf_img[i][c]= 1  Y[i]= 0  Ytrain[i]= 1
# c= 0 res[i]= 1  cf_img[i][c]= 1  Y[i]= 0  Ytrain[i]= 1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 8  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 9  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 2  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 4  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 8  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 6  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 6  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 5  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 8  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 3  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 4  Ytrain[i]= -1
# c= 0 res[i]= 1  cf_img[i][c]= 1  Y[i]= 0  Ytrain[i]= 1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 5  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 5  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 8  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 3  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 6  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 2  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 3  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 9  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 2  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 5  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 2  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 3  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 2  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 8  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 7  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 3  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 7  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 2  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 4  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 6  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 9  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 7  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 2  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 4  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 2  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 8  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 3  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 8  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 4  Ytrain[i]= -1
# c= 0 res[i]= 1  cf_img[i][c]= 1  Y[i]= 0  Ytrain[i]= 1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 6  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 5  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 9  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 3  Ytrain[i]= -1
# c= 0 res[i]= 1  cf_img[i][c]= 1  Y[i]= 0  Ytrain[i]= 1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 9  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 2  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 4  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 7  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 2  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 9  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 4  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 2  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 6  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 8  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 9  Ytrain[i]= -1
# c= 0 res[i]= 1  cf_img[i][c]= 1  Y[i]= 0  Ytrain[i]= 1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 6  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 6  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 7  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 9  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 9  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 8  Ytrain[i]= -1
# c= 0 res[i]= 1  cf_img[i][c]= 1  Y[i]= 0  Ytrain[i]= 1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 4  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 4  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 6  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 7  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 5  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 7  Ytrain[i]= -1
# c= 0 res[i]= 1  cf_img[i][c]= 1  Y[i]= 0  Ytrain[i]= 1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 3  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 5  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 8  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 4  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 7  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 2  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 5  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 9  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 5  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 6  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 7  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 5  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 9  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 8  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 8  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 3  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 6  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 9  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 7  Ytrain[i]= -1
# c= 0 res[i]= 1  cf_img[i][c]= 1  Y[i]= 0  Ytrain[i]= 1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 7  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 5  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 7  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= 1  cf_img[i][c]= 1  Y[i]= 0  Ytrain[i]= 1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 7  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 9  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 2  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 3  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 7  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 3  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 2  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 4  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 6  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 2  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 7  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 5  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 5  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 7  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 4  Ytrain[i]= -1
# c= 0 res[i]= 1  cf_img[i][c]= 1  Y[i]= 0  Ytrain[i]= 1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 2  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 6  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 3  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 6  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 4  Ytrain[i]= -1
# c= 0 res[i]= 1  cf_img[i][c]= 1  Y[i]= 0  Ytrain[i]= 1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 4  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 2  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 6  Ytrain[i]= -1
# c= 0 res[i]= 1  cf_img[i][c]= 1  Y[i]= 0  Ytrain[i]= 1
# c= 0 res[i]= 1  cf_img[i][c]= 1  Y[i]= 0  Ytrain[i]= 1
# c= 0 res[i]= 1  cf_img[i][c]= 1  Y[i]= 0  Ytrain[i]= 1
# c= 0 res[i]= 1  cf_img[i][c]= 1  Y[i]= 0  Ytrain[i]= 1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 3  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 6  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 2  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 2  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 3  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 4  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 5  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 4  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 6  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 4  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 7  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 2  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 8  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 7  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 9  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 2  Ytrain[i]= -1
# c= 0 res[i]= 1  cf_img[i][c]= 1  Y[i]= 0  Ytrain[i]= 1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 5  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 4  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 2  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 8  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 3  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 2  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 4  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 5  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 4  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 6  Ytrain[i]= -1
# c= 0 res[i]= 1  cf_img[i][c]= 1  Y[i]= 0  Ytrain[i]= 1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 7  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 9  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 8  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 4  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 9  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 8  Ytrain[i]= -1
# c= 0 res[i]= 1  cf_img[i][c]= 1  Y[i]= 0  Ytrain[i]= 1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= 1  cf_img[i][c]= 1  Y[i]= 0  Ytrain[i]= 1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 2  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 2  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 3  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 2  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 4  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 4  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 5  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 8  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 6  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 5  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 7  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 7  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 8  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 8  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 9  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 7  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 4  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 7  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 3  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 2  Ytrain[i]= -1
# c= 0 res[i]= 1  cf_img[i][c]= 1  Y[i]= 0  Ytrain[i]= 1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 8  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 6  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 8  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 6  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 6  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 8  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 9  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 4  Ytrain[i]= -1
# c= 0 res[i]= 1  cf_img[i][c]= 1  Y[i]= 0  Ytrain[i]= 1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 9  Ytrain[i]= -1
# c= 0 res[i]= 1  cf_img[i][c]= 1  Y[i]= 0  Ytrain[i]= 1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 4  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 5  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 4  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 7  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 5  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 3  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 7  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 4  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 9  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 8  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 5  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 8  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 6  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 3  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 8  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 6  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 9  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 9  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 8  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 3  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 5  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 8  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 6  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 5  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 9  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 7  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 2  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 5  Ytrain[i]= -1
# c= 0 res[i]= 1  cf_img[i][c]= 1  Y[i]= 0  Ytrain[i]= 1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 8  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 5  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= 1  cf_img[i][c]= 1  Y[i]= 0  Ytrain[i]= 1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 9  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 8  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 6  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 7  Ytrain[i]= -1
# c= 0 res[i]= 1  cf_img[i][c]= 1  Y[i]= 0  Ytrain[i]= 1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 9  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 3  Ytrain[i]= -1
# c= 0 res[i]= 1  cf_img[i][c]= 1  Y[i]= 0  Ytrain[i]= 1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 8  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 8  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 9  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 6  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 7  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 8  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 4  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 7  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 5  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 9  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 2  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 6  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 7  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 4  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 5  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 9  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 2  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 3  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 6  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 3  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 9  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 2  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 2  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 5  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 6  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 8  Ytrain[i]= -1
# c= 0 res[i]= 1  cf_img[i][c]= 1  Y[i]= 0  Ytrain[i]= 1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 7  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 7  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 1  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 9  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 8  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 7  Ytrain[i]= -1
# c= 0 res[i]= 1  cf_img[i][c]= 1  Y[i]= 0  Ytrain[i]= 1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 9  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 9  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 4  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 6  Ytrain[i]= -1
# c= 0 res[i]= -1  cf_img[i][c]= -1  Y[i]= 2  Ytrain[i]= -1
# ...
# Clase: 2  Aciertos: 99.0  Fallos: 0.0  img( 2 ): 99  Porcentaje de aciertos: 100.0 % Porcentaje de fallos: 0.0
# Clase: 3  Aciertos: 93.0  Fallos: 0.0  img( 3 ): 93  Porcentaje de aciertos: 100.0 % Porcentaje de fallos: 0.0
# Clase: 4  Aciertos: 105.0  Fallos: 0.0  img( 4 ): 105  Porcentaje de aciertos: 100.0 % Porcentaje de fallos: 0.0
# Clase: 5  Aciertos: 92.0  Fallos: 0.0  img( 5 ): 92  Porcentaje de aciertos: 100.0 % Porcentaje de fallos: 0.0
# Clase: 6  Aciertos: 94.0  Fallos: 0.0  img( 6 ): 94  Porcentaje de aciertos: 100.0 % Porcentaje de fallos: 0.0
# Clase: 7  Aciertos: 117.0  Fallos: 0.0  img( 7 ): 117  Porcentaje de aciertos: 100.0 % Porcentaje de fallos: 0.0
# Clase: 8  Aciertos: 87.0  Fallos: 0.0  img( 8 ): 87  Porcentaje de aciertos: 100.0 % Porcentaje de fallos: 0.0
# Clase: 9  Aciertos: 97.0  Fallos: 1.0  img( 9 ): 100  Porcentaje de aciertos: 97.0 % Porcentaje de fallos: 0.1
# Imagenes =  1000  | A =  1000  | T =  100  | Porcentaje de aciertos(Total) =  99.7 % Porcentaje de fallos(Total) =  0.1
# clase:  0  resultados test[ 1001 - 2000 ]:  98.5
# clase:  1  resultados test[ 1001 - 2000 ]:  97.7
# clase:  2  resultados test[ 1001 - 2000 ]:  94.19
# clase:  3  resultados test[ 1001 - 2000 ]:  94.29
# clase:  4  resultados test[ 1001 - 2000 ]:  94.39
# clase:  5  resultados test[ 1001 - 2000 ]:  93.79
# clase:  6  resultados test[ 1001 - 2000 ]:  97.6
# clase:  7  resultados test[ 1001 - 2000 ]:  96.7
# clase:  8  resultados test[ 1001 - 2000 ]:  93.39
# clase:  9  resultados test[ 1001 - 2000 ]:  93.39
# Resultados de prueba para: | 1001  -  2000 |:
# desde: 1001 hasta: 2000
# lenY: 999
# Aciertos Total: 743.0
# Fallos Total: 204.0
# Clase: 0  Aciertos: 83.0  Fallos: 5.0  img( 0 ): 93  Porcentaje de aciertos: 89.25 % Porcentaje de fallos: 0.5
# Clase: 1  Aciertos: 91.0  Fallos: 10.0  img( 1 ): 104  Porcentaje de aciertos: 87.5 % Porcentaje de fallos: 1.0
# Clase: 2  Aciertos: 63.0  Fallos: 22.0  img( 2 ): 99  Porcentaje de aciertos: 63.64 % Porcentaje de fallos: 2.2
# Clase: 3  Aciertos: 56.0  Fallos: 15.0  img( 3 ): 98  Porcentaje de aciertos: 57.14 % Porcentaje de fallos: 1.5
# Clase: 4  Aciertos: 77.0  Fallos: 24.0  img( 4 ): 109  Porcentaje de aciertos: 70.64 % Porcentaje de fallos: 2.4
# Clase: 5  Aciertos: 59.0  Fallos: 33.0  img( 5 ): 88  Porcentaje de aciertos: 67.05 % Porcentaje de fallos: 3.3
# Clase: 6  Aciertos: 92.0  Fallos: 10.0  img( 6 ): 106  Porcentaje de aciertos: 86.79 % Porcentaje de fallos: 1.0
# Clase: 7  Aciertos: 91.0  Fallos: 17.0  img( 7 ): 107  Porcentaje de aciertos: 85.05 % Porcentaje de fallos: 1.7
# Clase: 8  Aciertos: 63.0  Fallos: 44.0  img( 8 ): 85  Porcentaje de aciertos: 74.12 % Porcentaje de fallos: 4.4
# Clase: 9  Aciertos: 68.0  Fallos: 24.0  img( 9 ): 110  Porcentaje de aciertos: 61.82 % Porcentaje de fallos: 2.4
# Imagenes =  999  | A =  1000  | T =  100  | Porcentaje de aciertos(Total) =  74.37 % Porcentaje de fallos(Total) =  20.42
# clase:  0  resultados test[ 2001 - 3000 ]:  98.3
# clase:  1  resultados test[ 2001 - 3000 ]:  98.6
# clase:  2  resultados test[ 2001 - 3000 ]:  96.6
# clase:  3  resultados test[ 2001 - 3000 ]:  94.19
# clase:  4  resultados test[ 2001 - 3000 ]:  96.0
# clase:  5  resultados test[ 2001 - 3000 ]:  94.89
# clase:  6  resultados test[ 2001 - 3000 ]:  97.6
# clase:  7  resultados test[ 2001 - 3000 ]:  96.9
# clase:  8  resultados test[ 2001 - 3000 ]:  94.99
# clase:  9  resultados test[ 2001 - 3000 ]:  94.69
# Resultados de prueba para: | 2001  -  3000 |:
# desde: 2001 hasta: 3000
# lenY: 999
# Aciertos Total: 789.0
# Fallos Total: 162.0
# Clase: 0  Aciertos: 84.0  Fallos: 7.0  img( 0 ): 94  Porcentaje de aciertos: 89.36 % Porcentaje de fallos: 0.7
# Clase: 1  Aciertos: 113.0  Fallos: 8.0  img( 1 ): 119  Porcentaje de aciertos: 94.96 % Porcentaje de fallos: 0.8
# Clase: 2  Aciertos: 83.0  Fallos: 16.0  img( 2 ): 101  Porcentaje de aciertos: 82.18 % Porcentaje de fallos: 1.6
# Clase: 3  Aciertos: 63.0  Fallos: 17.0  img( 3 ): 104  Porcentaje de aciertos: 60.58 % Porcentaje de fallos: 1.7
# Clase: 4  Aciertos: 89.0  Fallos: 18.0  img( 4 ): 111  Porcentaje de aciertos: 80.18 % Porcentaje de fallos: 1.8
# Clase: 5  Aciertos: 68.0  Fallos: 26.0  img( 5 ): 93  Porcentaje de aciertos: 73.12 % Porcentaje de fallos: 2.6
# Clase: 6  Aciertos: 95.0  Fallos: 13.0  img( 6 ): 106  Porcentaje de aciertos: 89.62 % Porcentaje de fallos: 1.3
# Clase: 7  Aciertos: 87.0  Fallos: 13.0  img( 7 ): 105  Porcentaje de aciertos: 82.86 % Porcentaje de fallos: 1.3
# Clase: 8  Aciertos: 61.0  Fallos: 22.0  img( 8 ): 89  Porcentaje de aciertos: 68.54 % Porcentaje de fallos: 2.2
# Clase: 9  Aciertos: 46.0  Fallos: 22.0  img( 9 ): 77  Porcentaje de aciertos: 59.74 % Porcentaje de fallos: 2.2
# Imagenes =  999  | A =  1000  | T =  100  | Porcentaje de aciertos(Total) =  78.98 % Porcentaje de fallos(Total) =  16.22
# clase:  0  resultados test[ 3001 - 4000 ]:  98.7
# clase:  1  resultados test[ 3001 - 4000 ]:  98.2
# clase:  2  resultados test[ 3001 - 4000 ]:  95.6
# clase:  3  resultados test[ 3001 - 4000 ]:  95.8
# clase:  4  resultados test[ 3001 - 4000 ]:  94.99
# clase:  5  resultados test[ 3001 - 4000 ]:  94.59
# clase:  6  resultados test[ 3001 - 4000 ]:  97.4
# clase:  7  resultados test[ 3001 - 4000 ]:  96.4
# clase:  8  resultados test[ 3001 - 4000 ]:  94.19
# clase:  9  resultados test[ 3001 - 4000 ]:  91.79
# Resultados de prueba para: | 3001  -  4000 |:
# desde: 3001 hasta: 4000
# lenY: 999
# Aciertos Total: 780.0
# Fallos Total: 204.0
# Clase: 0  Aciertos: 88.0  Fallos: 7.0  img( 0 ): 94  Porcentaje de aciertos: 93.62 % Porcentaje de fallos: 0.7
# Clase: 1  Aciertos: 99.0  Fallos: 12.0  img( 1 ): 105  Porcentaje de aciertos: 94.29 % Porcentaje de fallos: 1.2
# Clase: 2  Aciertos: 79.0  Fallos: 25.0  img( 2 ): 98  Porcentaje de aciertos: 80.61 % Porcentaje de fallos: 2.5
# Clase: 3  Aciertos: 73.0  Fallos: 18.0  img( 3 ): 97  Porcentaje de aciertos: 75.26 % Porcentaje de fallos: 1.8
# Clase: 4  Aciertos: 80.0  Fallos: 25.0  img( 4 ): 105  Porcentaje de aciertos: 76.19 % Porcentaje de fallos: 2.5
# Clase: 5  Aciertos: 49.0  Fallos: 27.0  img( 5 ): 76  Porcentaje de aciertos: 64.47 % Porcentaje de fallos: 2.7
# Clase: 6  Aciertos: 81.0  Fallos: 8.0  img( 6 ): 99  Porcentaje de aciertos: 81.82 % Porcentaje de fallos: 0.8
# Clase: 7  Aciertos: 90.0  Fallos: 22.0  img( 7 ): 104  Porcentaje de aciertos: 86.54 % Porcentaje de fallos: 2.2
# Clase: 8  Aciertos: 78.0  Fallos: 24.0  img( 8 ): 112  Porcentaje de aciertos: 69.64 % Porcentaje de fallos: 2.4
# Clase: 9  Aciertos: 63.0  Fallos: 36.0  img( 9 ): 109  Porcentaje de aciertos: 57.8 % Porcentaje de fallos: 3.6
# Imagenes =  999  | A =  1000  | T =  100  | Porcentaje de aciertos(Total) =  78.08 % Porcentaje de fallos(Total) =  20.42
# clase:  0  resultados test[ 4001 - 5000 ]:  98.4
# clase:  1  resultados test[ 4001 - 5000 ]:  98.7
# clase:  2  resultados test[ 4001 - 5000 ]:  93.99
# clase:  3  resultados test[ 4001 - 5000 ]:  94.29
# clase:  4  resultados test[ 4001 - 5000 ]:  95.8
# clase:  5  resultados test[ 4001 - 5000 ]:  94.99
# clase:  6  resultados test[ 4001 - 5000 ]:  97.3
# clase:  7  resultados test[ 4001 - 5000 ]:  96.6
# clase:  8  resultados test[ 4001 - 5000 ]:  94.39
# clase:  9  resultados test[ 4001 - 5000 ]:  91.49
# Resultados de prueba para: | 4001  -  5000 |:
# desde: 4001 hasta: 5000
# lenY: 999
# Aciertos Total: 771.0
# Fallos Total: 212.0
# Clase: 0  Aciertos: 90.0  Fallos: 6.0  img( 0 ): 100  Porcentaje de aciertos: 90.0 % Porcentaje de fallos: 0.6
# Clase: 1  Aciertos: 110.0  Fallos: 4.0  img( 1 ): 119  Porcentaje de aciertos: 92.44 % Porcentaje de fallos: 0.4
# Clase: 2  Aciertos: 66.0  Fallos: 35.0  img( 2 ): 91  Porcentaje de aciertos: 72.53 % Porcentaje de fallos: 3.5
# Clase: 3  Aciertos: 68.0  Fallos: 24.0  img( 3 ): 101  Porcentaje de aciertos: 67.33 % Porcentaje de fallos: 2.4
# Clase: 4  Aciertos: 87.0  Fallos: 24.0  img( 4 ): 105  Porcentaje de aciertos: 82.86 % Porcentaje de fallos: 2.4
# Clase: 5  Aciertos: 60.0  Fallos: 26.0  img( 5 ): 84  Porcentaje de aciertos: 71.43 % Porcentaje de fallos: 2.6
# Clase: 6  Aciertos: 84.0  Fallos: 15.0  img( 6 ): 96  Porcentaje de aciertos: 87.5 % Porcentaje de fallos: 1.5
# Clase: 7  Aciertos: 101.0  Fallos: 19.0  img( 7 ): 116  Porcentaje de aciertos: 87.07 % Porcentaje de fallos: 1.9
# Clase: 8  Aciertos: 52.0  Fallos: 19.0  img( 8 ): 89  Porcentaje de aciertos: 58.43 % Porcentaje de fallos: 1.9
# Clase: 9  Aciertos: 53.0  Fallos: 40.0  img( 9 ): 98  Porcentaje de aciertos: 54.08 % Porcentaje de fallos: 4.0
# Imagenes =  999  | A =  1000  | T =  100  | Porcentaje de aciertos(Total) =  77.18 % Porcentaje de fallos(Total) =  21.22
# clase:  0  resultados test[ 5001 - 6000 ]:  97.9
# clase:  1  resultados test[ 5001 - 6000 ]:  97.9
# clase:  2  resultados test[ 5001 - 6000 ]:  95.7
# clase:  3  resultados test[ 5001 - 6000 ]:  95.1
# clase:  4  resultados test[ 5001 - 6000 ]:  95.6
# clase:  5  resultados test[ 5001 - 6000 ]:  93.99
# clase:  6  resultados test[ 5001 - 6000 ]:  97.1
# clase:  7  resultados test[ 5001 - 6000 ]:  97.1
# clase:  8  resultados test[ 5001 - 6000 ]:  94.29
# clase:  9  resultados test[ 5001 - 6000 ]:  93.69
# Resultados de prueba para: | 5001  -  6000 |:
# desde: 5001 hasta: 6000
# lenY: 999
# Aciertos Total: 768.0
# Fallos Total: 185.0
# Clase: 0  Aciertos: 100.0  Fallos: 8.0  img( 0 ): 113  Porcentaje de aciertos: 88.5 % Porcentaje de fallos: 0.8
# Clase: 1  Aciertos: 96.0  Fallos: 9.0  img( 1 ): 108  Porcentaje de aciertos: 88.89 % Porcentaje de fallos: 0.9
# Clase: 2  Aciertos: 66.0  Fallos: 16.0  img( 2 ): 93  Porcentaje de aciertos: 70.97 % Porcentaje de fallos: 1.6
# Clase: 3  Aciertos: 80.0  Fallos: 14.0  img( 3 ): 115  Porcentaje de aciertos: 69.57 % Porcentaje de fallos: 1.4
# Clase: 4  Aciertos: 65.0  Fallos: 21.0  img( 4 ): 88  Porcentaje de aciertos: 73.86 % Porcentaje de fallos: 2.1
# Clase: 5  Aciertos: 53.0  Fallos: 33.0  img( 5 ): 80  Porcentaje de aciertos: 66.25 % Porcentaje de fallos: 3.3
# Clase: 6  Aciertos: 93.0  Fallos: 15.0  img( 6 ): 107  Porcentaje de aciertos: 86.92 % Porcentaje de fallos: 1.5
# Clase: 7  Aciertos: 86.0  Fallos: 15.0  img( 7 ): 100  Porcentaje de aciertos: 86.0 % Porcentaje de fallos: 1.5
# Clase: 8  Aciertos: 61.0  Fallos: 29.0  img( 8 ): 89  Porcentaje de aciertos: 68.54 % Porcentaje de fallos: 2.9
# Clase: 9  Aciertos: 68.0  Fallos: 25.0  img( 9 ): 106  Porcentaje de aciertos: 64.15 % Porcentaje de fallos: 2.5
# Imagenes =  999  | A =  1000  | T =  100  | Porcentaje de aciertos(Total) =  76.88 % Porcentaje de fallos(Total) =  18.52
# clase:  0  resultados test[ 6001 - 7000 ]:  98.3
# clase:  1  resultados test[ 6001 - 7000 ]:  98.3
# clase:  2  resultados test[ 6001 - 7000 ]:  95.5
# clase:  3  resultados test[ 6001 - 7000 ]:  95.2
# clase:  4  resultados test[ 6001 - 7000 ]:  97.1
# clase:  5  resultados test[ 6001 - 7000 ]:  93.39
# clase:  6  resultados test[ 6001 - 7000 ]:  98.2
# clase:  7  resultados test[ 6001 - 7000 ]:  96.2
# clase:  8  resultados test[ 6001 - 7000 ]:  93.19
# clase:  9  resultados test[ 6001 - 7000 ]:  93.99
# Resultados de prueba para: | 6001  -  7000 |:
# desde: 6001 hasta: 7000
# lenY: 999
# Aciertos Total: 775.0
# Fallos Total: 182.0
# Clase: 0  Aciertos: 88.0  Fallos: 6.0  img( 0 ): 99  Porcentaje de aciertos: 88.89 % Porcentaje de fallos: 0.6
# Clase: 1  Aciertos: 104.0  Fallos: 8.0  img( 1 ): 113  Porcentaje de aciertos: 92.04 % Porcentaje de fallos: 0.8
# Clase: 2  Aciertos: 65.0  Fallos: 16.0  img( 2 ): 94  Porcentaje de aciertos: 69.15 % Porcentaje de fallos: 1.6
# Clase: 3  Aciertos: 68.0  Fallos: 8.0  img( 3 ): 108  Porcentaje de aciertos: 62.96 % Porcentaje de fallos: 0.8
# Clase: 4  Aciertos: 79.0  Fallos: 15.0  img( 4 ): 93  Porcentaje de aciertos: 84.95 % Porcentaje de fallos: 1.5
# Clase: 5  Aciertos: 63.0  Fallos: 33.0  img( 5 ): 96  Porcentaje de aciertos: 65.62 % Porcentaje de fallos: 3.3
# Clase: 6  Aciertos: 91.0  Fallos: 9.0  img( 6 ): 100  Porcentaje de aciertos: 91.0 % Porcentaje de fallos: 0.9
# Clase: 7  Aciertos: 83.0  Fallos: 18.0  img( 7 ): 103  Porcentaje de aciertos: 80.58 % Porcentaje de fallos: 1.8
# Clase: 8  Aciertos: 69.0  Fallos: 38.0  img( 8 ): 99  Porcentaje de aciertos: 69.7 % Porcentaje de fallos: 3.8
# Clase: 9  Aciertos: 65.0  Fallos: 31.0  img( 9 ): 94  Porcentaje de aciertos: 69.15 % Porcentaje de fallos: 3.1
# Imagenes =  999  | A =  1000  | T =  100  | Porcentaje de aciertos(Total) =  77.58 % Porcentaje de fallos(Total) =  18.22
# clase:  0  resultados test[ 7001 - 8000 ]:  98.0
# clase:  1  resultados test[ 7001 - 8000 ]:  97.4
# clase:  2  resultados test[ 7001 - 8000 ]:  94.49
# clase:  3  resultados test[ 7001 - 8000 ]:  94.39
# clase:  4  resultados test[ 7001 - 8000 ]:  96.0
# clase:  5  resultados test[ 7001 - 8000 ]:  93.79
# clase:  6  resultados test[ 7001 - 8000 ]:  97.6
# clase:  7  resultados test[ 7001 - 8000 ]:  96.9
# clase:  8  resultados test[ 7001 - 8000 ]:  92.99
# clase:  9  resultados test[ 7001 - 8000 ]:  95.1
# Resultados de prueba para: | 7001  -  8000 |:
# desde: 7001 hasta: 8000
# lenY: 999
# Aciertos Total: 756.0
# Fallos Total: 190.0
# Clase: 0  Aciertos: 91.0  Fallos: 7.0  img( 0 ): 104  Porcentaje de aciertos: 87.5 % Porcentaje de fallos: 0.7
# Clase: 1  Aciertos: 111.0  Fallos: 15.0  img( 1 ): 122  Porcentaje de aciertos: 90.98 % Porcentaje de fallos: 1.5
# Clase: 2  Aciertos: 80.0  Fallos: 22.0  img( 2 ): 113  Porcentaje de aciertos: 70.8 % Porcentaje de fallos: 2.2
# Clase: 3  Aciertos: 61.0  Fallos: 22.0  img( 3 ): 95  Porcentaje de aciertos: 64.21 % Porcentaje de fallos: 2.2
# Clase: 4  Aciertos: 64.0  Fallos: 21.0  img( 4 ): 83  Porcentaje de aciertos: 77.11 % Porcentaje de fallos: 2.1
# Clase: 5  Aciertos: 58.0  Fallos: 28.0  img( 5 ): 92  Porcentaje de aciertos: 63.04 % Porcentaje de fallos: 2.8
# Clase: 6  Aciertos: 74.0  Fallos: 9.0  img( 6 ): 89  Porcentaje de aciertos: 83.15 % Porcentaje de fallos: 0.9
# Clase: 7  Aciertos: 83.0  Fallos: 15.0  img( 7 ): 99  Porcentaje de aciertos: 83.84 % Porcentaje de fallos: 1.5
# Clase: 8  Aciertos: 63.0  Fallos: 31.0  img( 8 ): 102  Porcentaje de aciertos: 61.76 % Porcentaje de fallos: 3.1
# Clase: 9  Aciertos: 71.0  Fallos: 20.0  img( 9 ): 100  Porcentaje de aciertos: 71.0 % Porcentaje de fallos: 2.0
# Imagenes =  999  | A =  1000  | T =  100  | Porcentaje de aciertos(Total) =  75.68 % Porcentaje de fallos(Total) =  19.02
# clase:  0  resultados test[ 8001 - 9000 ]:  97.6
# clase:  1  resultados test[ 8001 - 9000 ]:  98.0
# clase:  2  resultados test[ 8001 - 9000 ]:  94.59
# clase:  3  resultados test[ 8001 - 9000 ]:  92.89
# clase:  4  resultados test[ 8001 - 9000 ]:  95.4
# clase:  5  resultados test[ 8001 - 9000 ]:  93.59
# clase:  6  resultados test[ 8001 - 9000 ]:  97.5
# clase:  7  resultados test[ 8001 - 9000 ]:  95.4
# clase:  8  resultados test[ 8001 - 9000 ]:  92.09
# clase:  9  resultados test[ 8001 - 9000 ]:  92.49
# Resultados de prueba para: | 8001  -  9000 |:
# desde: 8001 hasta: 9000
# lenY: 999
# Aciertos Total: 732.0
# Fallos Total: 237.0
# Clase: 0  Aciertos: 82.0  Fallos: 11.0  img( 0 ): 95  Porcentaje de aciertos: 86.32 % Porcentaje de fallos: 1.1
# Clase: 1  Aciertos: 104.0  Fallos: 7.0  img( 1 ): 117  Porcentaje de aciertos: 88.89 % Porcentaje de fallos: 0.7
# Clase: 2  Aciertos: 70.0  Fallos: 23.0  img( 2 ): 101  Porcentaje de aciertos: 69.31 % Porcentaje de fallos: 2.3
# Clase: 3  Aciertos: 58.0  Fallos: 18.0  img( 3 ): 111  Porcentaje de aciertos: 52.25 % Porcentaje de fallos: 1.8
# Clase: 4  Aciertos: 81.0  Fallos: 27.0  img( 4 ): 100  Porcentaje de aciertos: 81.0 % Porcentaje de fallos: 2.7
# Clase: 5  Aciertos: 39.0  Fallos: 31.0  img( 5 ): 72  Porcentaje de aciertos: 54.17 % Porcentaje de fallos: 3.1
# Clase: 6  Aciertos: 93.0  Fallos: 8.0  img( 6 ): 110  Porcentaje de aciertos: 84.55 % Porcentaje de fallos: 0.8
# Clase: 7  Aciertos: 83.0  Fallos: 21.0  img( 7 ): 108  Porcentaje de aciertos: 76.85 % Porcentaje de fallos: 2.1
# Clase: 8  Aciertos: 57.0  Fallos: 43.0  img( 8 ): 93  Porcentaje de aciertos: 61.29 % Porcentaje de fallos: 4.3
# Clase: 9  Aciertos: 65.0  Fallos: 48.0  img( 9 ): 92  Porcentaje de aciertos: 70.65 % Porcentaje de fallos: 4.8
# Imagenes =  999  | A =  1000  | T =  100  | Porcentaje de aciertos(Total) =  73.27 % Porcentaje de fallos(Total) =  23.72

# %% [markdown]
# Y a continuacion obtendremos graficas comparativas a partir de resultados obtenidos en ejecuciones anteriores:

# %%
# Para A = 10
# T = [0, 50, 100, 150, 200, 250]      # Numero de clasificadores 
# resultados = [0, 20, 35, 56, 68] # Resultados obtenidos de clasificacion

# plt.title("Porcentajes con valores de T (A=10)")
# plt.plot(T, resultados)
# plt.show()

# Para A = 100
# T = [0, 50, 100, 150, 200, 250]      # Numero de clasificadores 
# resultados = [0, 20, 35, 56, 68] # Resultados obtenidos de clasificacion

# plt.title("Porcentajes con valores de T (A=100)")
# plt.plot(T, resultados)
# plt.show()

# Para A = 200
# T = [0, 50, 100, 150, 200, 250]      # Numero de clasificadores 
# resultados = [0, 20, 35, 56, 68] # Resultados obtenidos de clasificacion

# plt.title("Porcentajes con valores de T (A=200)")
# plt.plot(T, resultados)
# plt.show()

# Para A = 500
# T = [0, 50, 100, 150, 200, 250]      # Numero de clasificadores 
# resultados = [0, 20, 35, 56, 68] # Resultados obtenidos de clasificacion

# plt.title("Porcentajes con valores de T (A=500)")
# plt.plot(T, resultados)
# plt.show()

# Para A = 1000
# T = [0, 50, 100, 150, 200, 250]      # Numero de clasificadores 
# resultados = [0, 20, 35, 56, 68] # Resultados obtenidos de clasificacion

# plt.title("Porcentajes con valores de T (A=1000)")
# plt.plot(T, resultados)
# plt.show()
